# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('AutoData (1).csv')

# %%
df.shape
# Out:
# (205, 25)

# %%
df.head()
# Out:
#    symboling                      make fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         130        mpfi       3.47   2.68              9.0         111
# 1         130        mpfi       3.47   2.68              9.0         111
# 2         152        mpfi       2.68   3.47              9.0         154
# 3         109        mpfi       3.19   3.40             10.0         102
# 4         136        mpfi       3.19   3.40              8.0         115
#
#   peakrpm  citympg  highwaympg    price
# 0    5000       21          27  13495.0
# 1    5000       21          27  16500.0
# 2    5000       19          26  16500.0
# 3    5500       24          30  13950.0
# 4    5500       18          22  17450.0
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
# symboling           205 non-null int64
# make                205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# peakrpm             205 non-null int64
# citympg             205 non-null int64
# highwaympg          205 non-null int64
# price               205 non-null float64
# dtypes: float64(8), int64(7), object(10)
# memory usage: 40.1+ KB

# %%
df.isnull().sum()
# Out:
# symboling           0
# make                0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
plt.subplots(figsize=(15,10))
sns_plot = sns.heatmap(df.corr(),annot =True,cmap='rainbow_r',square=True)
fig = sns_plot.get_figure()
fig.savefig("corrHeatmap.png")

# %%
tempdf = df[{'symboling','enginetype','boreratio','horsepower', 'peakrpm', 'citympg', 'highwaympg','enginesize','price'}]

# %%
sns.pairplot(tempdf)

# %%
   for i in df.columns:
    plt.title(i)
    sns.scatterplot(df[i],df['price'])
    plt.show()

# %%
bestvar1 = ['wheelbase','carlength','carwidth','curbweigth','enginesize']

# %%
sns.distplot(df['price'])
plt.show()

# %% [markdown]
# we see there are cars highest in price range below 10000 $

# %% [markdown]
# # Data PreProcessing

# %%
df.columns
# Out:
# Index(['symboling', 'make', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df1 = df.drop({'make','carlength','carwidth','aspiration', 'doornumber','carbody','drivewheel','carheight',"enginelocation"},axis=1)

# %%
df1.columns
# Out:
# Index(['symboling', 'fueltype', 'wheelbase', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df1.head()
# Out:
#    symboling fueltype  wheelbase  curbweight enginetype cylindernumber  \
# 0          3      gas       88.6        2548       dohc           four
# 1          3      gas       88.6        2548       dohc           four
# 2          1      gas       94.5        2823       ohcv            six
# 3          2      gas       99.8        2337        ohc           four
# 4          2      gas       99.4        2824        ohc           five
#
#    enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130       mpfi       3.47    2.68               9.0         111
# 1         130       mpfi       3.47    2.68               9.0         111
# 2         152       mpfi       2.68    3.47               9.0         154
# 3         109       mpfi       3.19    3.40              10.0         102
# 4         136       mpfi       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
# 2     5000       19          26  16500.0
# 3     5500       24          30  13950.0
# 4     5500       18          22  17450.0

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df1['fueltype']= label_encoder.fit_transform(df['fueltype']) 
df1['fueltype'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1.head()
# Out:
#    symboling  fueltype  wheelbase  curbweight enginetype cylindernumber  \
# 0          3         1       88.6        2548       dohc           four
# 1          3         1       88.6        2548       dohc           four
# 2          1         1       94.5        2823       ohcv            six
# 3          2         1       99.8        2337        ohc           four
# 4          2         1       99.4        2824        ohc           five
#
#    enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130       mpfi       3.47    2.68               9.0         111
# 1         130       mpfi       3.47    2.68               9.0         111
# 2         152       mpfi       2.68    3.47               9.0         154
# 3         109       mpfi       3.19    3.40              10.0         102
# 4         136       mpfi       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
# 2     5000       19          26  16500.0
# 3     5500       24          30  13950.0
# 4     5500       18          22  17450.0

# %%
df1['enginetype']= label_encoder.fit_transform(df['enginetype']) 
df1['enginetype'].unique()
# Out:
# array([0, 5, 3, 2, 6, 4, 1], dtype=int64)

# %%
df1['fuelsystem']= label_encoder.fit_transform(df['fuelsystem']) 
df1['fuelsystem'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6], dtype=int64)

# %%
pip install word2number
# Out:
# Requirement already satisfied: word2number in c:\programdata\anaconda3\lib\site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from word2number import w2n

# %%
nums = []
for i in df1['cylindernumber']:
    x = w2n.word_to_num(i)
    nums.append(x)
df1['cylindernumber'] = nums

# %%
df1.head()
# Out:
#    symboling  fueltype  wheelbase  curbweight  enginetype  cylindernumber  \
# 0          3         1       88.6        2548           0               4
# 1          3         1       88.6        2548           0               4
# 2          1         1       94.5        2823           5               6
# 3          2         1       99.8        2337           3               4
# 4          2         1       99.4        2824           3               5
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130           5       3.47    2.68               9.0         111
# 1         130           5       3.47    2.68               9.0         111
# 2         152           5       2.68    3.47               9.0         154
# 3         109           5       3.19    3.40              10.0         102
# 4         136           5       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
# 2     5000       19          26  16500.0
# 3     5500       24          30  13950.0
# 4     5500       18          22  17450.0

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %%
X = df1[['horsepower']]
y = df1[['price']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)

# %%
LR = LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = LR.predict(X_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.27979618506336734

# %%
print('Coefficient is',LR.coef_[0][0])
print('intercept is',LR.intercept_[0])
# Out:
# Coefficient is 157.52524028053594
# intercept is -3241.804243638466

# %%
g = sns.jointplot(X,y,kind='reg',
                 joint_kws={'line_kws':{'color':'red'}})
plt.xlabel('HorsePower')
plt.ylabel('Price')
# Out:
# Text(27.125, 0.5, 'Price')

# %%
plt.scatter(X,y)
plt.plot(X,LR.predict(X))
plt.xlabel('HorsePower')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     1854.
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):          2.43e-104
# Time:                        21:49:39   Log-Likelihood:                -2031.7
# No. Observations:                 205   AIC:                             4065.
# Df Residuals:                     204   BIC:                             4069.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# horsepower   132.0043      3.066     43.055      0.000     125.959     138.049
# ==============================================================================
# Omnibus:                       83.232   Durbin-Watson:                   0.594
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.121
# Skew:                           1.804   Prob(JB):                     7.92e-50
# Kurtosis:                       6.667   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# We see the Regression LIne is in Best Fit¶

# %% [markdown]
# # RFE selected Feature

# %%
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler

# %%
X = df1.drop('price',axis=1)
y = df1['price']
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)

# %%
scaler = MinMaxScaler()
X_train1 = scaler.fit_transform(X_train)

# %%
model = LinearRegression()

# %%
rfe = RFE(model, 1)

# %%
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#   n_features_to_select=1, step=1, verbose=0)

# %%
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#   n_features_to_select=1, step=1, verbose=0)

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['boreratio'], dtype='object')

# %%
X = df[['boreratio']]
y = df[['price']]
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)
LR = LinearRegression()
LR.fit(X_train,y_train)
y_pred1 = LR.predict(X_train)
print("R2 score is",r2_score(y_pred,y_test))
print('Coefficient is',LR.coef_[0][0])
print('intercept is',LR.intercept_[0])
# Out:
# R2 score is 0.27979618506336734
# Coefficient is 15631.185368192808
# intercept is -38495.77664498373

# %%
plt.scatter(X,y)
plt.plot(X,LR.predict(X))
plt.xlabel('Boreratio')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
g = sns.jointplot(X,y,kind='reg',
                 joint_kws={'line_kws':{'color':'red'}})
plt.xlabel('Boreration')
plt.ylabel('Price')
# Out:
# Text(27.125, 0.5, 'Price')

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     683.8
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):           4.56e-67
# Time:                        21:53:37   Log-Likelihood:                -2117.9
# No. Observations:                 205   AIC:                             4238.
# Df Residuals:                     204   BIC:                             4241.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# boreratio   4067.9365    155.569     26.149      0.000    3761.207    4374.666
# ==============================================================================
# Omnibus:                       83.118   Durbin-Watson:                   0.457
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.690
# Skew:                           1.862   Prob(JB):                     4.82e-46
# Kurtosis:                       6.251   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Multiple Linear Regression

# %%
df1.columns
# Out:
# Index(['symboling', 'fueltype', 'wheelbase', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
X = df1.drop('price',axis=1)
y = df1['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.8,random_state=60)

# %%
LR.fit(X_train.values,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = LR.predict(X_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.8844051102486352

# %%
print('Coefficient is',LR.coef_)
print('intercept is',LR.intercept_)
# Out:
# Coefficient is [ 4.77467773e+01 -2.46714154e+03  2.42045768e+00  2.23762163e+02
#  -7.22737788e+01  1.09665515e+02  2.87341407e+02]
# intercept is -33225.35015568045

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     613.6
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):          1.59e-130
# Time:                        22:02:19   Log-Likelihood:                -1948.6
# No. Observations:                 205   AIC:                             3911.
# Df Residuals:                     198   BIC:                             3935.
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# horsepower          29.4598     14.773      1.994      0.048       0.327      58.592
# stroke           -3434.7640    756.536     -4.540      0.000   -4926.666   -1942.862
# peakrpm              1.3116      0.565      2.323      0.021       0.198       2.425
# wheelbase           18.4178     33.052      0.557      0.578     -46.762      83.598
# citympg           -265.8360     56.093     -4.739      0.000    -376.453    -155.219
# enginesize         122.3736     13.023      9.397      0.000      96.693     148.054
# compressionratio   399.0005     73.219      5.449      0.000     254.611     543.390
# ==============================================================================
# Omnibus:                       18.316   Durbin-Watson:                   0.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.614
# Skew:                           0.252   Prob(JB):                     2.28e-12
# Kurtosis:                       5.454   Cond. No.                     1.69e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# RFE Based features

# %%
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
model = LinearRegression()

# %%
## Selecting Top 7 Features
rfe = RFE(model, 7)
X_train1 = scaler.fit_transform(X_train)

# %%
rfe.fit(X_train1,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#   n_features_to_select=7, step=1, verbose=0)

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['horsepower', 'stroke', 'peakrpm', 'wheelbase', 'citympg', 'enginesize',
#        'compressionratio'],
#       dtype='object')

# %%
print("Num Features: %s" % (rfe.n_features_))
print("Selected Features: %s" % (rfe.support_))
print("Feature Ranking: %s" % (rfe.ranking_))
# Out:
# Num Features: 7
# Selected Features: [ True  True  True  True  True  True  True]
# Feature Ranking: [1 1 1 1 1 1 1]

# %%
X = df1[{'wheelbase', 'enginesize', 'stroke', 'compressionratio', 'horsepower',
       'peakrpm', 'citympg'}]
y = df1['price']
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.8,random_state=60)

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
y_pred1 = LR.predict(X_train)
print("R2 score is",r2_score(y_pred,y_test))
print('intercept is',LR.intercept_)
print('Coefficient are',LR.coef_)
# Out:
# R2 score is 0.8844051102486352
# intercept is -33225.35015568045
# Coefficient are [ 4.77467773e+01 -2.46714154e+03  2.42045768e+00  2.23762163e+02
#  -7.22737788e+01  1.09665515e+02  2.87341407e+02]

# %% [markdown]
# conclusion:
#
#         Curbweight of a car, location of the engine and the range operated in by the company of a car have a strong influence on the pricing of a car. If an engine is located at the rear end of the car it positively influences the price as cars with rear engines are Rear Wheel Drives and are mainly find in high end racing cars for better steering and other benefits. Also if a car is manufactured by car companies like Honda or Toyota, its price would be generally less than the of a car manufactured by companies like BMW and Porche. Hence a negative association between car price and low - mid range car companies.
